# %%
#W7A1
def binary_search(lis,key):
    left=0
    right=len(lis)-1
    while(left<=right):
        mid=(left+right)//2
        if lis[mid]==key:
            return mid
        elif lis[mid]>key:
            right=mid-1
        else:left=mid+1
    return -1
a=list(map(int,input().split()))
n=int(input())
print(binary_search(a,n))
# Out:
# 3

# %%
#W7A2
a=list(map(int,input().split()))
n=int(input())
d={}
for i in a:
    if i in d:
        d[i]+=1
    else:d[i]=1
if n in d:
    print(d[n])
else:print(0)
# Out:
# 0

# %%
#W7A3
def bubble_sort(list):
    for i in range(0,len(list)):
        kt_swap=False
        for j in range(0,len(list)-1):
            if(a[j]>a[j+1]):
                a[j],a[j+1]=a[j+1],a[j]
                kt_swap=True
        if kt_swap==False:
            break
    return list
def selection_sort(list):
    for i in range(0,len(list)):
        min=a[i]
        kt=False
        for j in range(i+1,len(list)):
            if min>a[j] :
                min=a[j]
                k=j
                kt=True
        if kt==True:
            a[i],a[k]=a[k],a[i]
        else: continue
    return list
a=list(map(int,input().split()))
a=selection_sort(a)
for i in a:
    print(i,end=' ')
# Out:
# 1 3 4 60 70 90 100 1000

# %%
#W7A4
a=list(map(int,input().split()))
d={}
mark={}
for i in a:
    if i not in d:
        d[i]=1
    else:d[i]+=1
max=0
for i in d:
    if max<d[i]: max=d[i]
for i in d:
    if max==d[i]:mark[i]=True
for i in a:
    if i in mark:
        res=i
        break
print(f"{res} xuat hien nhieu nhat,som nhat,{d[res]} lan")
# Out:
# 1 xuat hien nhieu nhat,som nhat,4 lan

# %%
#W7A5
def binary_search(list,key):
    left,right=0,len(a)-1
    while(left<=right):
        mid=(left+right)/2
        if list[mid]==key:
            return mid
        elif list[mid]>key:
            right=mid-1
        else: left=mid+1
    return left

a=list(map(int,input().split()))
x=int(input())
d=0
for i in range(0,len(a)):
    
print(d)
# Out:
# 4

# %%
#W7A6
a=input()
d=[]
res=''
for i in a:
    if i.isdigit()==True or i==',':
        d.append(i)
for i in d:
    res+=i
lis=list(map(str,res.split(',')))
kq=[]
for i in lis:
    if i!='':
        kq.append(int(i))
print(kq)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#W7A7
def binary_search(list,key):
    left,right=0,len(list)-1
    while(left<=right):
        mid=(left+right)//2
        if list[mid]==key:
            return (mid,True)
        elif list[mid]>key:
            right=mid-1
        else:left=mid+1
    return (left,False)
a=input()
a=a[1:len(a)-1:]
a=list(map(int,a.split(',')))
d=[0]*1
d[0]=a[0]
a.pop(0)
for i in a:
    if i>d[len(d)-1]:
        d.append(i)
    else:
        tup=binary_search(d,i)
        if tup[1]==True:
            continue
        else:
            d[tup[0]]=i
print(len(d))
# Out:
# 5

# %%
#W7A8
def binary_search(list,key):
    left,right=0,len(list)-1
    if key>list[len(list)-1]:return len(list)-1
    while(left<=right):
        mid=(left+right)//2
        if list[mid]==key:
            return mid
        elif list[mid]>key:
            right=mid-1
        else:left=mid+1
    return left
a=input()
b=input()
b=b[1:len(b)-1:]
queries=list(map(int,b.split(',')))
a=a[1:len(a)-1:]
a=list(map(str,a.split('],')))
time=[]
for i in a:
    i=i[1:len(i):]
    if i[0]=='[':
        i=i[1:len(i):]
    if i[len(i)-1]==']':
        i=i[0:len(i)-1:]
    m,n=i.split(',')
    time.append([int(m),int(n)])
que_mod=[]
for i in queries:
    que_mod.append([i,9999999])
time_mod=[]
for i in time:
    delta=i[1]-i[0]+1
    time_mod.append([delta,i[0],i[1]])
time_mod.sort()
for i in time:
    delta=i[1]-i[0]+1
    left=binary_search(queries,i[0])
    right=binary_search(queries,i[1])
    for j in range(left,right+1):
        if(delta<que_mod[j][1]):
            que_mod[j][1]=delta
res=[]
for i in que_mod:
    res.append(i[1])
print(res)

# %%
#W7A9

def binary_search(list,key):
    left,right=0,len(list)-1
    while(left<=right):
        mid=(left+right)//2
        if list[mid]==key:
            return (mid,True)
        elif list[mid]>key:
            right=mid-1
        else:left=mid+1
    return (left,False)
a=input()
a=a[1:len(a)-1:]
a=list(map(int,a.split(',')))
d=[0]*1
d[0]=a[0]
a.pop(0)
for i in a:
    if i>d[len(d)-1]:
        d.append(i)
    else:
        tup=binary_search(d,i)
        if tup[1]==True:
            continue
        else:
            d[tup[0]]=i
print(len(d))

# %%
#W7A10
a=list(map(int,input().split()))
n=int(input())
b=[0]*len(a)
b[0]=a[0]
for i in range(0,len(a)):
    b[i]

# %%
#W7A11
a=input()
b=input()
d=0
for i in range(len(a)-len(b)+1):
    key=a[i:i+len(b):]
    if key==b:
        d+=1
print(d)

# %%
#W7A12
a=list(map(int,input().split()))
d={}
kq=[]
for i in a:
    if i in d:
        d[i]+=1
    else:
        d[i]=1
for i in d:
    if d[i]==0:continue
    else:
        if i+1 not in d:
            continue
        else:kq.append(d[i]+d[i+1])
print(max(kq))

# %%
#W7A14
def tim7(list):
    res=[]
    for i in range(0,len(list)):
        if list[i]==7:
            res.append(i)
    if len(res)==0:
        return "Not found"
    else:return res[::-1]
n=int(input())
a=list(map(int,input().split()))
k=tim7(a)
if type(k)==str:
    print(k)
else:
    for i in k:
        print(i,end=" ")

# %%
#W7A14
iuh

# %%
#W7A15
âfw
